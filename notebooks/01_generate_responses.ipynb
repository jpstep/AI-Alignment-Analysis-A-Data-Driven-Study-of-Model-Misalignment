# %% [markdown]
# # Generate Model Responses
#
# This notebook loads alignment-related prompts and generates model responses for analysis.
#
# **Important:** Raw model outputs are saved locally and are not committed to the repository.

# %%
import pandas as pd
from pathlib import Path

# %%
DATA_DIR = Path("../data")
RAW_PATH = DATA_DIR / "raw" / "prompts.csv"
PROCESSED_DIR = DATA_DIR / "processed"

df = pd.read_csv(RAW_PATH)
df.head()

# %% [markdown]
# ## TODO: Model Inference
#
# Insert your preferred model call here (OpenAI, open-source, etc.).
# Store outputs locally and **do not commit them**.
